# %%
# !git clone https://github.com/NeurAI-Lab/CLS-ER
# Out:
# Cloning into 'CLS-ER'...
# remote: Enumerating objects: 86, done.
# remote: Counting objects: 100% (86/86), done.
# remote: Compressing objects: 100% (69/69), done.
# remote: Total 86 (delta 20), reused 75 (delta 16), pack-reused 0
# Unpacking objects: 100% (86/86), done.

# %%
# %cd /content/CLS-ER
# Out:
# /content/CLS-ER

# %%
# !pwd
# Out:
# /content/CLS-ER

# %% [markdown]
# Seq-mnist

# %%
# !python main.py --dataset seq-mnist --model clser --buffer_size 200 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='seq-mnist', experiment_id='cl', load_best_args=True, model='clser', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# ...
# 100% 9912422/9912422 [00:00<00:00, 97677881.70it/s]
# Extracting ./datasets/MNIST/MyMNIST/raw/train-images-idx3-ubyte.gz to ./datasets/MNIST/MyMNIST/raw
#
# ...
# 100% 28881/28881 [00:00<00:00, 31036560.04it/s]
# Extracting ./datasets/MNIST/MyMNIST/raw/train-labels-idx1-ubyte.gz to ./datasets/MNIST/MyMNIST/raw
#
# ...
# 100% 1648877/1648877 [00:00<00:00, 34492879.85it/s]
# Extracting ./datasets/MNIST/MyMNIST/raw/t10k-images-idx3-ubyte.gz to ./datasets/MNIST/MyMNIST/raw
#
# ...
# 100% 4542/4542 [00:00<00:00, 30876059.59it/s]
# Extracting ./datasets/MNIST/MyMNIST/raw/t10k-labels-idx1-ubyte.gz to ./datasets/MNIST/MyMNIST/raw
#
# ...
# 100% 9912422/9912422 [00:00<00:00, 109030169.29it/s]
# Extracting ./datasets/MNIST/MNIST/raw/train-images-idx3-ubyte.gz to ./datasets/MNIST/MNIST/raw
#
# ...

# %%
# !python main.py --dataset seq-mnist --model clser --buffer_size 200 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='seq-mnist', experiment_id='cl', load_best_args=True, model='clser', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Task 0 Accuracy: 10.070921985815604
# Task 1 Accuracy: 8.570029382957884
# Task 2 Accuracy: 0.8537886872998933
# Task 3 Accuracy: 7.099697885196375
# Task 4 Accuracy: 8.724155320221886
#
# /content/CLS-ER/models/clser.py:129: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# ...

# %%
# !python main.py --dataset seq-mnist --model clser --buffer_size 200 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='seq-mnist', experiment_id='cl', load_best_args=True, model='clser', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Task 0 Accuracy: 0.28368794326241137
# Task 1 Accuracy: 28.256611165524
# Task 2 Accuracy: 6.670224119530416
# Task 3 Accuracy: 23.867069486404834
# Task 4 Accuracy: 0.2521432173474533
#
# /content/CLS-ER/models/clser.py:129: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# ...

# %%
# !python main.py --dataset seq-mnist --model clser --buffer_size 500 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='seq-mnist', experiment_id='cl', load_best_args=True, model='clser', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# ...
# 100% 9912422/9912422 [00:00<00:00, 55257237.47it/s]
# Extracting ./datasets/MNIST/MyMNIST/raw/train-images-idx3-ubyte.gz to ./datasets/MNIST/MyMNIST/raw
#
# ...
# 100% 28881/28881 [00:00<00:00, 132533581.86it/s]
# Extracting ./datasets/MNIST/MyMNIST/raw/train-labels-idx1-ubyte.gz to ./datasets/MNIST/MyMNIST/raw
#
# ...
# 100% 1648877/1648877 [00:00<00:00, 15534451.93it/s]
# Extracting ./datasets/MNIST/MyMNIST/raw/t10k-images-idx3-ubyte.gz to ./datasets/MNIST/MyMNIST/raw
#
# ...
# 100% 4542/4542 [00:00<00:00, 19088706.18it/s]
# Extracting ./datasets/MNIST/MyMNIST/raw/t10k-labels-idx1-ubyte.gz to ./datasets/MNIST/MyMNIST/raw
#
# ...
# 100% 9912422/9912422 [00:00<00:00, 73359667.51it/s]
# Extracting ./datasets/MNIST/MNIST/raw/train-images-idx3-ubyte.gz to ./datasets/MNIST/MNIST/raw
#
# ...

# %%
# !python main.py --dataset seq-mnist --model clser --buffer_size 500 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='seq-mnist', experiment_id='cl', load_best_args=True, model='clser', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Task 0 Accuracy: 17.77777777777778
# Task 1 Accuracy: 2.0078354554358473
# Task 2 Accuracy: 6.830309498399147
# Task 3 Accuracy: 3.7764350453172204
# Task 4 Accuracy: 0.15128593040847202
#
# /content/CLS-ER/models/clser.py:129: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# ...

# %%
# !python main.py --dataset seq-mnist --model clser --buffer_size 500 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='seq-mnist', experiment_id='cl', load_best_args=True, model='clser', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# ...
# 100% 9912422/9912422 [00:00<00:00, 355530282.57it/s]
# Extracting ./datasets/MNIST/MyMNIST/raw/train-images-idx3-ubyte.gz to ./datasets/MNIST/MyMNIST/raw
#
# ...
# 100% 28881/28881 [00:00<00:00, 145946619.07it/s]
# Extracting ./datasets/MNIST/MyMNIST/raw/train-labels-idx1-ubyte.gz to ./datasets/MNIST/MyMNIST/raw
#
# ...
# 100% 1648877/1648877 [00:00<00:00, 187280421.27it/s]
# Extracting ./datasets/MNIST/MyMNIST/raw/t10k-images-idx3-ubyte.gz to ./datasets/MNIST/MyMNIST/raw
#
# ...
# 100% 4542/4542 [00:00<00:00, 30677179.98it/s]
# Extracting ./datasets/MNIST/MyMNIST/raw/t10k-labels-idx1-ubyte.gz to ./datasets/MNIST/MyMNIST/raw
#
# ...
# 100% 9912422/9912422 [00:00<00:00, 293096307.68it/s]
# Extracting ./datasets/MNIST/MNIST/raw/train-images-idx3-ubyte.gz to ./datasets/MNIST/MNIST/raw
#
# ...

# %%
# !python main.py --dataset seq-mnist --model clser --buffer_size 5120 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='seq-mnist', experiment_id='cl', load_best_args=True, model='clser', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Task 0 Accuracy: 0.0
# Task 1 Accuracy: 5.093046033300686
# Task 2 Accuracy: 2.934898612593383
# Task 3 Accuracy: 27.0392749244713
# Task 4 Accuracy: 0.8572869389813415
#
# /content/CLS-ER/models/clser.py:129: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# ...

# %%
# !python main.py --dataset seq-mnist --model clser --buffer_size 5120 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='seq-mnist', experiment_id='cl', load_best_args=True, model='clser', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Task 0 Accuracy: 12.43498817966903
# Task 1 Accuracy: 0.4407443682664055
# Task 2 Accuracy: 21.237993596584843
# Task 3 Accuracy: 0.5538771399798591
# Task 4 Accuracy: 21.02874432677761
#
# /content/CLS-ER/models/clser.py:129: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# ...

# %%
# !python main.py --dataset seq-mnist --model clser --buffer_size 5120 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='seq-mnist', experiment_id='cl', load_best_args=True, model='clser', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Task 0 Accuracy: 4.7281323877068555
# Task 1 Accuracy: 13.907933398628794
# Task 2 Accuracy: 5.176093916755603
# Task 3 Accuracy: 8.157099697885197
# Task 4 Accuracy: 7.2617246596066565
#
# /content/CLS-ER/models/clser.py:129: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# ...

# %%
# !python main.py --dataset seq-mnist --model clser --buffer_size 1 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='seq-mnist', experiment_id='cl', load_best_args=True, model='clser', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# ...
# 100% 9912422/9912422 [00:00<00:00, 97261771.21it/s]
# Extracting ./datasets/MNIST/MyMNIST/raw/train-images-idx3-ubyte.gz to ./datasets/MNIST/MyMNIST/raw
#
# ...
# 100% 28881/28881 [00:00<00:00, 65267076.41it/s]
# Extracting ./datasets/MNIST/MyMNIST/raw/train-labels-idx1-ubyte.gz to ./datasets/MNIST/MyMNIST/raw
#
# ...
# 100% 1648877/1648877 [00:00<00:00, 25558562.39it/s]
# Extracting ./datasets/MNIST/MyMNIST/raw/t10k-images-idx3-ubyte.gz to ./datasets/MNIST/MyMNIST/raw
#
# ...
# 100% 4542/4542 [00:00<00:00, 32179947.24it/s]
# Extracting ./datasets/MNIST/MyMNIST/raw/t10k-labels-idx1-ubyte.gz to ./datasets/MNIST/MyMNIST/raw
#
# ...
# 100% 9912422/9912422 [00:00<00:00, 98010847.00it/s]
# Extracting ./datasets/MNIST/MNIST/raw/train-images-idx3-ubyte.gz to ./datasets/MNIST/MNIST/raw
#
# ...

# %%
# !python main.py --dataset seq-mnist --model clser --buffer_size 10 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='seq-mnist', experiment_id='cl', load_best_args=True, model='clser', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Task 0 Accuracy: 0.0
# Task 1 Accuracy: 3.330068560235064
# Task 2 Accuracy: 0.05336179295624333
# Task 3 Accuracy: 48.690835850956695
# Task 4 Accuracy: 0.0
#
# /content/CLS-ER/models/clser.py:129: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# ...

# %%
# !python main.py --dataset seq-mnist --model clser --buffer_size 100 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='seq-mnist', experiment_id='cl', load_best_args=True, model='clser', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Task 0 Accuracy: 10.969267139479905
# Task 1 Accuracy: 4.35847208619001
# Task 2 Accuracy: 0.7470651013874066
# Task 3 Accuracy: 0.4028197381671702
# Task 4 Accuracy: 25.920322743318202
#
# /content/CLS-ER/models/clser.py:129: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# ...

# %%
# !python main.py --dataset seq-mnist --model clser --buffer_size 1000 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='seq-mnist', experiment_id='cl', load_best_args=True, model='clser', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Task 0 Accuracy: 8.55791962174941
# Task 1 Accuracy: 1.860920666013712
# Task 2 Accuracy: 1.2273212379935965
# Task 3 Accuracy: 26.33434038267875
# Task 4 Accuracy: 3.429147755925366
#
# /content/CLS-ER/models/clser.py:129: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# ...

# %%
# !python main.py --dataset seq-mnist --model clser --buffer_size 10000 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='seq-mnist', experiment_id='cl', load_best_args=True, model='clser', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Task 0 Accuracy: 31.15839243498818
# Task 1 Accuracy: 6.660137120470128
# Task 2 Accuracy: 7.417289220917824
# Task 3 Accuracy: 1.460221550855992
# Task 4 Accuracy: 9.379727685325264
#
# /content/CLS-ER/models/clser.py:129: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# ...

# %%
# !python main.py --dataset seq-mnist --model clser --buffer_size 100000 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='seq-mnist', experiment_id='cl', load_best_args=True, model='clser', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Task 0 Accuracy: 0.2364066193853428
# Task 1 Accuracy: 3.281096963761019
# Task 2 Accuracy: 22.838847385272146
# Task 3 Accuracy: 5.085599194360524
# Task 4 Accuracy: 18.709026727181037
#
# /content/CLS-ER/models/clser.py:129: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# ...

# %%
# !python main.py --dataset seq-mnist --model clser --buffer_size 1000000 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='seq-mnist', experiment_id='cl', load_best_args=True, model='clser', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Task 0 Accuracy: 0.04728132387706856
# Task 1 Accuracy: 5.093046033300686
# Task 2 Accuracy: 0.5336179295624333
# Task 3 Accuracy: 36.70694864048338
# Task 4 Accuracy: 0.3530005042864347
#
# /content/CLS-ER/models/clser.py:129: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# ...

# %% [markdown]
# Sequential Tiny ImageNet

# %%
# !python main.py --dataset seq-tinyimg --model clser --buffer_size 500 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='seq-tinyimg', experiment_id='cl', load_best_args=True, model='clser', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# ...
# Unzipping.../usr/local/lib/python3.7/dist-packages/google_drive_downloader/google_drive_downloader.py:78: UserWarning: Ignoring `unzip` since "1Sy3ScMBr0F4se8VZ6TAwDYF-nNGAAdxj" does not look like a valid zip file
#   warnings.warn('Ignoring `unzip` since "{}" does not look like a valid zip file'.format(file_id))
# Traceback (most recent call last):
#   File "main.py", line 86, in <module>
#     main()
#   File "main.py", line 79, in main
#     train(model, dataset, args)
#   File "/content/CLS-ER/utils/training.py", line 150, in train
#     _, _ = dataset_copy.get_data_loaders()
#   File "/content/CLS-ER/datasets/seq_tinyimagenet.py", line 132, in get_data_loaders
#     train=True, download=True, transform=transform)
#   File "/content/CLS-ER/datasets/seq_tinyimagenet.py", line 91, in __init__
# ...

# %% [markdown]
# Permuted MNIST

# %%
# !python main.py --dataset perm-mnist --model clser --buffer_size 500 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='perm-mnist', experiment_id='cl', load_best_args=True, model='clser', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# Task 0 Accuracy: 16.21
# Task 1 Accuracy: 9.33
# Task 2 Accuracy: 5.9799999999999995
# Task 3 Accuracy: 12.5
# Task 4 Accuracy: 6.45
# Task 5 Accuracy: 14.530000000000001
# Task 6 Accuracy: 11.85
# Task 7 Accuracy: 13.74
# Task 8 Accuracy: 7.739999999999999
# Task 9 Accuracy: 8.77
# Task 10 Accuracy: 9.33
# Task 11 Accuracy: 7.28
# Task 12 Accuracy: 7.32
# Task 13 Accuracy: 14.49
# Task 14 Accuracy: 5.9799999999999995
# Task 15 Accuracy: 7.99
# Task 16 Accuracy: 6.710000000000001
# Task 17 Accuracy: 10.280000000000001
# Task 18 Accuracy: 15.85
# Task 19 Accuracy: 3.2800000000000002
#
# /content/CLS-ER/models/clser.py:129: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# ...

# %%
# !python main.py --dataset perm-mnist --model clser --buffer_size 200 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='perm-mnist', experiment_id='cl', load_best_args=True, model='clser', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# Task 0 Accuracy: 11.16
# Task 1 Accuracy: 10.24
# Task 2 Accuracy: 12.08
# Task 3 Accuracy: 10.11
# Task 4 Accuracy: 10.68
# Task 5 Accuracy: 10.17
# Task 6 Accuracy: 9.2
# Task 7 Accuracy: 8.3
# Task 8 Accuracy: 9.73
# Task 9 Accuracy: 9.950000000000001
# Task 10 Accuracy: 9.06
# Task 11 Accuracy: 10.73
# Task 12 Accuracy: 9.62
# Task 13 Accuracy: 10.18
# Task 14 Accuracy: 10.41
# Task 15 Accuracy: 11.020000000000001
# Task 16 Accuracy: 6.569999999999999
# Task 17 Accuracy: 9.91
# Task 18 Accuracy: 10.459999999999999
# Task 19 Accuracy: 10.02
#
# /content/CLS-ER/models/clser.py:129: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# ...

# %%
# !python main.py --dataset perm-mnist --model clser --buffer_size 5120 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='perm-mnist', experiment_id='cl', load_best_args=True, model='clser', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# Task 0 Accuracy: 5.94
# Task 1 Accuracy: 6.09
# Task 2 Accuracy: 7.03
# Task 3 Accuracy: 9.92
# Task 4 Accuracy: 10.51
# Task 5 Accuracy: 14.499999999999998
# Task 6 Accuracy: 10.07
# Task 7 Accuracy: 11.360000000000001
# Task 8 Accuracy: 8.64
# Task 9 Accuracy: 9.66
# Task 10 Accuracy: 9.229999999999999
# Task 11 Accuracy: 8.86
# Task 12 Accuracy: 11.55
# Task 13 Accuracy: 7.489999999999999
# Task 14 Accuracy: 11.600000000000001
# Task 15 Accuracy: 6.569999999999999
# Task 16 Accuracy: 14.149999999999999
# Task 17 Accuracy: 11.1
# Task 18 Accuracy: 7.969999999999999
# Task 19 Accuracy: 14.790000000000001
#
# /content/CLS-ER/models/clser.py:129: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# ...

# %% [markdown]
# Rotated MNIST

# %%
# !python main.py --dataset rot-mnist --model clser --buffer_size 500 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='rot-mnist', experiment_id='cl', load_best_args=True, model='clser', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# Task 0 Accuracy: 9.07
# Task 1 Accuracy: 13.139999999999999
# Task 2 Accuracy: 11.19
# Task 3 Accuracy: 11.24
# Task 4 Accuracy: 9.62
# Task 5 Accuracy: 11.19
# Task 6 Accuracy: 9.62
# Task 7 Accuracy: 8.0
# Task 8 Accuracy: 12.879999999999999
# Task 9 Accuracy: 9.75
# Task 10 Accuracy: 9.1
# Task 11 Accuracy: 9.68
# Task 12 Accuracy: 12.1
# Task 13 Accuracy: 7.66
# Task 14 Accuracy: 12.22
# Task 15 Accuracy: 9.9
# Task 16 Accuracy: 9.73
# Task 17 Accuracy: 10.54
# Task 18 Accuracy: 10.65
# Task 19 Accuracy: 11.110000000000001
#
# /content/CLS-ER/models/clser.py:129: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# ...

# %%
# !python main.py --dataset rot-mnist --model clser --buffer_size 500 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='rot-mnist', experiment_id='cl', load_best_args=True, model='clser', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# Task 0 Accuracy: 5.12
# Task 1 Accuracy: 8.6
# Task 2 Accuracy: 8.39
# Task 3 Accuracy: 10.34
# Task 4 Accuracy: 10.03
# Task 5 Accuracy: 7.07
# Task 6 Accuracy: 13.530000000000001
# Task 7 Accuracy: 5.79
# Task 8 Accuracy: 10.05
# Task 9 Accuracy: 8.99
# Task 10 Accuracy: 10.32
# Task 11 Accuracy: 4.9
# Task 12 Accuracy: 8.68
# Task 13 Accuracy: 9.950000000000001
# Task 14 Accuracy: 6.69
# Task 15 Accuracy: 11.33
# Task 16 Accuracy: 8.89
# Task 17 Accuracy: 13.0
# Task 18 Accuracy: 12.78
# Task 19 Accuracy: 4.9799999999999995
#
# /content/CLS-ER/models/clser.py:129: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# ...

# %%
# !python main.py --dataset rot-mnist --model clser --buffer_size 500 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='rot-mnist', experiment_id='cl', load_best_args=True, model='clser', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# Task 0 Accuracy: 9.91
# Task 1 Accuracy: 12.740000000000002
# Task 2 Accuracy: 7.91
# Task 3 Accuracy: 10.72
# Task 4 Accuracy: 10.05
# Task 5 Accuracy: 8.52
# Task 6 Accuracy: 10.42
# Task 7 Accuracy: 8.24
# Task 8 Accuracy: 10.83
# Task 9 Accuracy: 9.89
# Task 10 Accuracy: 12.620000000000001
# Task 11 Accuracy: 10.69
# Task 12 Accuracy: 10.95
# Task 13 Accuracy: 11.64
# Task 14 Accuracy: 11.61
# Task 15 Accuracy: 9.62
# Task 16 Accuracy: 11.360000000000001
# Task 17 Accuracy: 7.090000000000001
# Task 18 Accuracy: 7.1499999999999995
# Task 19 Accuracy: 8.72
#
# /content/CLS-ER/models/clser.py:129: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# ...

# %%
# !python main.py --dataset rot-mnist --model clser --buffer_size 200 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='rot-mnist', experiment_id='cl', load_best_args=True, model='clser', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# Task 0 Accuracy: 7.31
# Task 1 Accuracy: 6.59
# Task 2 Accuracy: 9.87
# Task 3 Accuracy: 7.5
# Task 4 Accuracy: 9.49
# Task 5 Accuracy: 7.1
# Task 6 Accuracy: 6.58
# Task 7 Accuracy: 9.68
# Task 8 Accuracy: 11.64
# Task 9 Accuracy: 6.63
# Task 10 Accuracy: 9.13
# Task 11 Accuracy: 7.9399999999999995
# Task 12 Accuracy: 11.39
# Task 13 Accuracy: 6.7
# Task 14 Accuracy: 7.85
# Task 15 Accuracy: 8.870000000000001
# Task 16 Accuracy: 7.829999999999999
# Task 17 Accuracy: 7.670000000000001
# Task 18 Accuracy: 12.98
# Task 19 Accuracy: 9.51
#
# /content/CLS-ER/models/clser.py:129: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# ...

# %%
# !python main.py --dataset rot-mnist --model clser --buffer_size 200 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='rot-mnist', experiment_id='cl', load_best_args=True, model='clser', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# Task 0 Accuracy: 4.78
# Task 1 Accuracy: 4.5
# Task 2 Accuracy: 7.670000000000001
# Task 3 Accuracy: 7.249999999999999
# Task 4 Accuracy: 4.72
# Task 5 Accuracy: 7.430000000000001
# Task 6 Accuracy: 8.62
# Task 7 Accuracy: 6.2
# Task 8 Accuracy: 7.76
# Task 9 Accuracy: 9.24
# Task 10 Accuracy: 8.43
# Task 11 Accuracy: 9.39
# Task 12 Accuracy: 8.36
# Task 13 Accuracy: 5.970000000000001
# Task 14 Accuracy: 8.200000000000001
# Task 15 Accuracy: 11.360000000000001
# Task 16 Accuracy: 9.43
# Task 17 Accuracy: 8.72
# Task 18 Accuracy: 8.95
# Task 19 Accuracy: 9.520000000000001
#
# /content/CLS-ER/models/clser.py:129: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# ...

# %%
# !python main.py --dataset rot-mnist --model clser --buffer_size 200 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='rot-mnist', experiment_id='cl', load_best_args=True, model='clser', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# Task 0 Accuracy: 6.79
# Task 1 Accuracy: 9.5
# Task 2 Accuracy: 8.16
# Task 3 Accuracy: 7.049999999999999
# Task 4 Accuracy: 9.42
# Task 5 Accuracy: 10.91
# Task 6 Accuracy: 9.26
# Task 7 Accuracy: 9.24
# Task 8 Accuracy: 11.86
# Task 9 Accuracy: 9.25
# Task 10 Accuracy: 17.62
# Task 11 Accuracy: 11.88
# Task 12 Accuracy: 11.690000000000001
# Task 13 Accuracy: 10.61
# Task 14 Accuracy: 9.91
# Task 15 Accuracy: 17.18
# Task 16 Accuracy: 5.93
# Task 17 Accuracy: 7.6899999999999995
# Task 18 Accuracy: 9.26
# Task 19 Accuracy: 9.969999999999999
#
# /content/CLS-ER/models/clser.py:129: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# ...

# %%
# !python main.py --dataset rot-mnist --model clser --buffer_size 5120 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='rot-mnist', experiment_id='cl', load_best_args=True, model='clser', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# Task 0 Accuracy: 11.74
# Task 1 Accuracy: 13.65
# Task 2 Accuracy: 14.469999999999999
# Task 3 Accuracy: 14.24
# Task 4 Accuracy: 15.89
# Task 5 Accuracy: 12.72
# Task 6 Accuracy: 8.459999999999999
# Task 7 Accuracy: 14.17
# Task 8 Accuracy: 10.69
# Task 9 Accuracy: 14.97
# Task 10 Accuracy: 13.370000000000001
# Task 11 Accuracy: 11.09
# Task 12 Accuracy: 9.48
# Task 13 Accuracy: 13.020000000000001
# Task 14 Accuracy: 16.54
# Task 15 Accuracy: 9.700000000000001
# Task 16 Accuracy: 7.969999999999999
# Task 17 Accuracy: 8.540000000000001
# Task 18 Accuracy: 13.84
# Task 19 Accuracy: 14.08
#
# /content/CLS-ER/models/clser.py:129: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# ...

# %%
# !python main.py --dataset rot-mnist --model clser --buffer_size 5120 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='rot-mnist', experiment_id='cl', load_best_args=True, model='clser', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# Task 0 Accuracy: 10.35
# Task 1 Accuracy: 9.610000000000001
# Task 2 Accuracy: 9.9
# Task 3 Accuracy: 8.790000000000001
# Task 4 Accuracy: 8.64
# Task 5 Accuracy: 10.83
# Task 6 Accuracy: 10.09
# Task 7 Accuracy: 9.32
# Task 8 Accuracy: 10.39
# Task 9 Accuracy: 12.879999999999999
# Task 10 Accuracy: 10.03
# Task 11 Accuracy: 10.35
# Task 12 Accuracy: 11.24
# Task 13 Accuracy: 10.67
# Task 14 Accuracy: 11.86
# Task 15 Accuracy: 10.13
# Task 16 Accuracy: 9.790000000000001
# Task 17 Accuracy: 9.32
# Task 18 Accuracy: 11.219999999999999
# Task 19 Accuracy: 10.65
#
# /content/CLS-ER/models/clser.py:129: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# ...

# %%
# !python main.py --dataset rot-mnist --model clser --buffer_size 5120 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='rot-mnist', experiment_id='cl', load_best_args=True, model='clser', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# Task 0 Accuracy: 7.380000000000001
# Task 1 Accuracy: 10.91
# Task 2 Accuracy: 12.379999999999999
# Task 3 Accuracy: 8.129999999999999
# Task 4 Accuracy: 8.08
# Task 5 Accuracy: 6.460000000000001
# Task 6 Accuracy: 10.26
# Task 7 Accuracy: 11.01
# Task 8 Accuracy: 8.01
# Task 9 Accuracy: 9.9
# Task 10 Accuracy: 9.73
# Task 11 Accuracy: 10.440000000000001
# Task 12 Accuracy: 8.450000000000001
# Task 13 Accuracy: 8.780000000000001
# Task 14 Accuracy: 8.24
# Task 15 Accuracy: 10.67
# Task 16 Accuracy: 11.39
# Task 17 Accuracy: 11.940000000000001
# Task 18 Accuracy: 8.06
# Task 19 Accuracy: 10.05
#
# /content/CLS-ER/models/clser.py:129: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# ...

# %% [markdown]
# Table 2

# %% [markdown]
# MNIST-360

# %%
# !python main.py --dataset mnist-360 --model clser --buffer_size 500 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='mnist-360', experiment_id='cl', load_best_args=True, model='clser', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# /content/CLS-ER/models/clser.py:129: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at  ../torch/csrc/utils/python_arg_parser.cpp:1174.)
#   ema_param.data.mul_(alpha).add_(1 - alpha, param.data)
# [ 10-25 | 03:32 ] Task C | epoch 0: |██████████████████████████████████████████████████| loss: 0.26202744Accuracy: 71.1155600044489
# ...
# Evaluating plastic_model
# ...
# Accuracy: 70.84862640418196
# ...
# Evaluating stable_model
# ...
# Accuracy: 69.98109220331442

# %%
# !python main.py --dataset mnist-360 --model clser --buffer_size 500 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='mnist-360', experiment_id='cl', load_best_args=True, model='clser', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# ...
# 100% 9912422/9912422 [00:00<00:00, 96489784.31it/s]
# Extracting ./datasets/MNIST/MyMNIST/raw/train-images-idx3-ubyte.gz to ./datasets/MNIST/MyMNIST/raw
#
# ...
# 100% 28881/28881 [00:00<00:00, 119463208.90it/s]
# Extracting ./datasets/MNIST/MyMNIST/raw/train-labels-idx1-ubyte.gz to ./datasets/MNIST/MyMNIST/raw
#
# ...
# 100% 1648877/1648877 [00:00<00:00, 80106231.57it/s]
# Extracting ./datasets/MNIST/MyMNIST/raw/t10k-images-idx3-ubyte.gz to ./datasets/MNIST/MyMNIST/raw
#
# ...
# 100% 4542/4542 [00:00<00:00, 27293021.16it/s]
# Extracting ./datasets/MNIST/MyMNIST/raw/t10k-labels-idx1-ubyte.gz to ./datasets/MNIST/MyMNIST/raw
#
# ...
# 100% 9912422/9912422 [00:00<00:00, 247971891.50it/s]
# Extracting ./datasets/MNIST/MNIST/raw/train-images-idx3-ubyte.gz to ./datasets/MNIST/MNIST/raw
#
# ...

# %%
# !python main.py --dataset mnist-360 --model clser --buffer_size 500 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='mnist-360', experiment_id='cl', load_best_args=True, model='clser', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# /content/CLS-ER/models/clser.py:129: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at  ../torch/csrc/utils/python_arg_parser.cpp:1174.)
#   ema_param.data.mul_(alpha).add_(1 - alpha, param.data)
# [ 10-29 | 01:52 ] Task C | epoch 0: |██████████████████████████████████████████████████| loss: 0.19971618Accuracy: 73.0174619063508
# ...
# Evaluating plastic_model
# ...
# Accuracy: 74.08519630741853
# ...
# Evaluating stable_model
# ...
# Accuracy: 72.92848403959515

# %%
# !python main.py --dataset mnist-360 --model clser --buffer_size 200 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='mnist-360', experiment_id='cl', load_best_args=True, model='clser', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# /content/CLS-ER/models/clser.py:129: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at  ../torch/csrc/utils/python_arg_parser.cpp:1174.)
#   ema_param.data.mul_(alpha).add_(1 - alpha, param.data)
# [ 10-25 | 03:33 ] Task C | epoch 0: |██████████████████████████████████████████████████| loss: 0.07412729Accuracy: 58.09142475809143
# ...
# Evaluating plastic_model
# ...
# Accuracy: 58.29162495829162
# ...
# Evaluating stable_model
# ...
# Accuracy: 58.04693582471361

# %%
# !python main.py --dataset mnist-360 --model clser --buffer_size 200 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='mnist-360', experiment_id='cl', load_best_args=True, model='clser', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# /content/CLS-ER/models/clser.py:129: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at  ../torch/csrc/utils/python_arg_parser.cpp:1174.)
#   ema_param.data.mul_(alpha).add_(1 - alpha, param.data)
# [ 10-29 | 01:53 ] Task C | epoch 0: |██████████████████████████████████████████████████| loss: 0.20928663Accuracy: 54.25425425425425
# ...
# Evaluating plastic_model
# ...
# Accuracy: 53.63140918696474
# ...
# Evaluating stable_model
# ...
# Accuracy: 54.39884328773218

# %%
# !python main.py --dataset mnist-360 --model clser --buffer_size 200 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='mnist-360', experiment_id='cl', load_best_args=True, model='clser', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# /content/CLS-ER/models/clser.py:129: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at  ../torch/csrc/utils/python_arg_parser.cpp:1174.)
#   ema_param.data.mul_(alpha).add_(1 - alpha, param.data)
# [ 10-29 | 01:54 ] Task C | epoch 0: |██████████████████████████████████████████████████| loss: 0.09770725Accuracy: 56.65665665665666
# ...
# Evaluating plastic_model
# ...
# Accuracy: 56.9458347236125
# ...
# Evaluating stable_model
# ...
# Accuracy: 56.82349015682349

# %%
# !python main.py --dataset mnist-360 --model clser --buffer_size 1000 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='mnist-360', experiment_id='cl', load_best_args=True, model='clser', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# /content/CLS-ER/models/clser.py:129: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at  ../torch/csrc/utils/python_arg_parser.cpp:1174.)
#   ema_param.data.mul_(alpha).add_(1 - alpha, param.data)
# [ 10-29 | 01:55 ] Task C | epoch 0: |██████████████████████████████████████████████████| loss: 0.09402755Accuracy: 79.17917917917919
# ...
# Evaluating plastic_model
# ...
# Accuracy: 78.87887887887888
# ...
# Evaluating stable_model
# ...
# Accuracy: 78.78990101212324

# %%
# !python main.py --dataset mnist-360 --model clser --buffer_size 1000 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='mnist-360', experiment_id='cl', load_best_args=True, model='clser', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# /content/CLS-ER/models/clser.py:129: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at  ../torch/csrc/utils/python_arg_parser.cpp:1174.)
#   ema_param.data.mul_(alpha).add_(1 - alpha, param.data)
# [ 10-29 | 01:56 ] Task C | epoch 0: |██████████████████████████████████████████████████| loss: 0.08351883Accuracy: 78.82326771215659
# ...
# Evaluating plastic_model
# ...
# Accuracy: 78.55633411188967
# ...
# Evaluating stable_model
# ...
# Accuracy: 78.26715604493383

# %%
# !python main.py --dataset mnist-360 --model clser --buffer_size 1000 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='mnist-360', experiment_id='cl', load_best_args=True, model='clser', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# /content/CLS-ER/models/clser.py:129: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at  ../torch/csrc/utils/python_arg_parser.cpp:1174.)
#   ema_param.data.mul_(alpha).add_(1 - alpha, param.data)
# [ 10-29 | 01:57 ] Task C | epoch 0: |██████████████████████████████████████████████████| loss: 0.18039036Accuracy: 77.9001223445668
# ...
# Evaluating plastic_model
# ...
# Accuracy: 78.17817817817819
# ...
# Evaluating stable_model
# ...
# Accuracy: 78.73428984540095

# %%
# !python main.py --dataset mnist-360 --model er --buffer_size 200 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='mnist-360', experiment_id='cl', load_best_args=True, model='er', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# ...
# 100% 9912422/9912422 [00:00<00:00, 71868375.08it/s]
# Extracting ./datasets/MNIST/MyMNIST/raw/train-images-idx3-ubyte.gz to ./datasets/MNIST/MyMNIST/raw
#
# ...
# 100% 28881/28881 [00:00<00:00, 122483006.90it/s]
# Extracting ./datasets/MNIST/MyMNIST/raw/train-labels-idx1-ubyte.gz to ./datasets/MNIST/MyMNIST/raw
#
# ...
# 100% 1648877/1648877 [00:00<00:00, 29628656.61it/s]
# Extracting ./datasets/MNIST/MyMNIST/raw/t10k-images-idx3-ubyte.gz to ./datasets/MNIST/MyMNIST/raw
#
# ...
# 100% 4542/4542 [00:00<00:00, 23519171.32it/s]
# Extracting ./datasets/MNIST/MyMNIST/raw/t10k-labels-idx1-ubyte.gz to ./datasets/MNIST/MyMNIST/raw
#
# ...
# 100% 9912422/9912422 [00:00<00:00, 84771231.17it/s]
# Extracting ./datasets/MNIST/MNIST/raw/train-images-idx3-ubyte.gz to ./datasets/MNIST/MNIST/raw
#
# ...

# %%
# !python main.py --dataset mnist-360 --model er --buffer_size 500 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='mnist-360', experiment_id='cl', load_best_args=True, model='er', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# Traceback (most recent call last):
#   File "main.py", line 86, in <module>
#     main()
#   File "main.py", line 81, in main
#     assert not hasattr(model, 'end_task')
# AssertionError

# %%
# !python main.py --dataset mnist-360 --model er --buffer_size 1000 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='mnist-360', experiment_id='cl', load_best_args=True, model='er', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# Traceback (most recent call last):
#   File "main.py", line 86, in <module>
#     main()
#   File "main.py", line 81, in main
#     assert not hasattr(model, 'end_task')
# AssertionError

# %%
# !python main.py --dataset mnist-360 --model mer --buffer_size 200 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='mnist-360', experiment_id='cl', load_best_args=True, model='mer', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# [ 10-25 | 14:42 ] Task C | epoch 0: |█████████████████████████████████████████████████┈| loss: 0.00011Accuracy: 45.968190412634854

# %%
# !python main.py --dataset mnist-360 --model mer --buffer_size 200 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='mnist-360', experiment_id='cl', load_best_args=True, model='mer', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# [ 10-29 | 02:10 ] Task C | epoch 0: |█████████████████████████████████████████████████┈| loss: 4.74e-05Accuracy: 50.461572683794905

# %%
# !python main.py --dataset mnist-360 --model mer --buffer_size 200 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='mnist-360', experiment_id='cl', load_best_args=True, model='mer', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# [ 10-29 | 02:24 ] Task C | epoch 0: |█████████████████████████████████████████████████┈| loss: 5.026e-05Accuracy: 48.559670781893004

# %%
# !python main.py --dataset mnist-360 --model mer --buffer_size 500 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='mnist-360', experiment_id='cl', load_best_args=True, model='mer', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# [ 10-25 | 05:25 ] Task C | epoch 0: |█████████████████████████████████████████████████┈| loss: 6.175e-05Accuracy: 63.06306306306306

# %%
# !python main.py --dataset mnist-360 --model mer --buffer_size 500 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='mnist-360', experiment_id='cl', load_best_args=True, model='mer', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# [ 10-29 | 02:37 ] Task C | epoch 0: |█████████████████████████████████████████████████┈| loss: 0.00013867Accuracy: 62.99632966299633

# %%
# !python main.py --dataset mnist-360 --model mer --buffer_size 500 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='mnist-360', experiment_id='cl', load_best_args=True, model='mer', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# [ 10-29 | 02:51 ] Task C | epoch 0: |█████████████████████████████████████████████████┈| loss: 0.00016861Accuracy: 63.36336336336337

# %%
# !python main.py --dataset mnist-360 --model mer --buffer_size 1000 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='mnist-360', experiment_id='cl', load_best_args=True, model='mer', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# [ 10-25 | 05:37 ] Task C | epoch 0: |█████████████████████████████████████████████████┈| loss: 0.00025698Accuracy: 68.90223556890224

# %%
# !python main.py --dataset mnist-360 --model mer --buffer_size 1000 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='mnist-360', experiment_id='cl', load_best_args=True, model='mer', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# ...
# 100% 9912422/9912422 [00:00<00:00, 109054192.37it/s]
# Extracting ./datasets/MNIST/MyMNIST/raw/train-images-idx3-ubyte.gz to ./datasets/MNIST/MyMNIST/raw
#
# ...
# 100% 28881/28881 [00:00<00:00, 116701053.78it/s]
# Extracting ./datasets/MNIST/MyMNIST/raw/train-labels-idx1-ubyte.gz to ./datasets/MNIST/MyMNIST/raw
#
# ...
# 100% 1648877/1648877 [00:00<00:00, 253654553.33it/s]
# Extracting ./datasets/MNIST/MyMNIST/raw/t10k-images-idx3-ubyte.gz to ./datasets/MNIST/MyMNIST/raw
#
# ...
# 100% 4542/4542 [00:00<00:00, 22333562.45it/s]
# Extracting ./datasets/MNIST/MyMNIST/raw/t10k-labels-idx1-ubyte.gz to ./datasets/MNIST/MyMNIST/raw
#
# ...
# 100% 9912422/9912422 [00:00<00:00, 372432087.68it/s]
# Extracting ./datasets/MNIST/MNIST/raw/train-images-idx3-ubyte.gz to ./datasets/MNIST/MNIST/raw
#
# ...

# %%
# !python main.py --dataset mnist-360 --model mer --buffer_size 1000 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='mnist-360', experiment_id='cl', load_best_args=True, model='mer', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# [ 10-29 | 03:53 ] Task C | epoch 0: |█████████████████████████████████████████████████┈| loss: 0.00050661Accuracy: 69.69191413635858

# %%
# !python main.py --dataset mnist-360 --model gss --buffer_size 200 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='mnist-360', experiment_id='cl', load_best_args=True, model='gss', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# Traceback (most recent call last):
#   File "main.py", line 86, in <module>
#     main()
#   File "main.py", line 50, in main
#     best = best_args[args.dataset][args.model]
# KeyError: 'gss'

# %%
# !python main.py --dataset mnist-360 --model gss --buffer_size 500 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='mnist-360', experiment_id='cl', load_best_args=True, model='gss', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# Traceback (most recent call last):
#   File "main.py", line 86, in <module>
#     main()
#   File "main.py", line 50, in main
#     best = best_args[args.dataset][args.model]
# KeyError: 'gss'

# %%
# !python main.py --dataset mnist-360 --model gss --buffer_size 1000 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='mnist-360', experiment_id='cl', load_best_args=True, model='gss', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# Traceback (most recent call last):
#   File "main.py", line 86, in <module>
#     main()
#   File "main.py", line 50, in main
#     best = best_args[args.dataset][args.model]
# KeyError: 'gss'

# %%
# !python main.py --dataset mnist-360 --model derpp --buffer_size 200 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='mnist-360', experiment_id='cl', load_best_args=True, model='derpp', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# Traceback (most recent call last):
#   File "main.py", line 86, in <module>
#     main()
#   File "main.py", line 81, in main
#     assert not hasattr(model, 'end_task')
# AssertionError

# %%
# !python main.py --dataset mnist-360 --model derpp --buffer_size 500 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='mnist-360', experiment_id='cl', load_best_args=True, model='derpp', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# Traceback (most recent call last):
#   File "main.py", line 86, in <module>
#     main()
#   File "main.py", line 81, in main
#     assert not hasattr(model, 'end_task')
# AssertionError

# %%
# !python main.py --dataset mnist-360 --model derpp --buffer_size 1000 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='mnist-360', experiment_id='cl', load_best_args=True, model='derpp', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# Traceback (most recent call last):
#   File "main.py", line 86, in <module>
#     main()
#   File "main.py", line 81, in main
#     assert not hasattr(model, 'end_task')
# AssertionError

# %%
# !python main.py --dataset mnist-360 --model joint --load_best_args
# Out:
# Namespace(csv_log=False, dataset='mnist-360', experiment_id='cl', load_best_args=True, model='joint', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# Traceback (most recent call last):
#   File "main.py", line 86, in <module>
#     main()
#   File "main.py", line 81, in main
#     assert not hasattr(model, 'end_task')
# AssertionError

# %%
# !python main.py --dataset mnist-360 --model sgd --load_best_args
# Out:
# Namespace(csv_log=False, dataset='mnist-360', experiment_id='cl', load_best_args=True, model='sgd', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# [ 10-25 | 05:38 ] Task C | epoch 0: |██████████████████████████████████████████████████| loss: 4.565e-05Accuracy: 20.64286508730953

# %% [markdown]
# Table1 SGD model

# %%
# !python main.py --dataset seq-mnist --model sgd --load_best_args
# Out:
# Namespace(csv_log=False, dataset='seq-mnist', experiment_id='cl', load_best_args=True, model='sgd', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Task 0 Accuracy: 0.04728132387706856
# Task 1 Accuracy: 22.722820763956904
# Task 2 Accuracy: 12.913553895410887
# Task 3 Accuracy: 0.10070493454179255
# Task 4 Accuracy: 25.063035804336863
#
# [ 10-26 | 01:31 ] Task 1 | epoch 0: |██████████████████████████████████████████████████| loss: 0.00287933
# ******************************
# ...

# %%
# !python main.py --dataset perm-mnist --model sgd --load_best_args
# Out:
# Namespace(csv_log=False, dataset='perm-mnist', experiment_id='cl', load_best_args=True, model='sgd', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# Task 0 Accuracy: 9.09
# Task 1 Accuracy: 14.11
# Task 2 Accuracy: 10.2
# Task 3 Accuracy: 11.200000000000001
# Task 4 Accuracy: 8.200000000000001
# Task 5 Accuracy: 10.86
# Task 6 Accuracy: 9.92
# Task 7 Accuracy: 9.65
# Task 8 Accuracy: 11.06
# Task 9 Accuracy: 6.41
# Task 10 Accuracy: 10.84
# Task 11 Accuracy: 9.49
# Task 12 Accuracy: 9.78
# Task 13 Accuracy: 10.43
# Task 14 Accuracy: 9.89
# Task 15 Accuracy: 14.799999999999999
# Task 16 Accuracy: 8.53
# Task 17 Accuracy: 12.120000000000001
# Task 18 Accuracy: 8.36
# Task 19 Accuracy: 7.28
#
# [ 10-26 | 01:33 ] Task 1 | epoch 0: |██████████████████████████████████████████████████| loss: 0.26929134
# ******************************
# Evaluating Model
# ******************************
# Task 0 Accuracy: 94.19
#
# Accuracy for 1 task(s): 94.19 %
# ...

# %%
# !python main.py --dataset rot-mnist --model sgd --load_best_args
# Out:
# Namespace(csv_log=False, dataset='rot-mnist', experiment_id='cl', load_best_args=True, model='sgd', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# Task 0 Accuracy: 13.83
# Task 1 Accuracy: 10.530000000000001
# Task 2 Accuracy: 10.290000000000001
# Task 3 Accuracy: 14.680000000000001
# Task 4 Accuracy: 13.750000000000002
# Task 5 Accuracy: 13.18
# Task 6 Accuracy: 9.06
# Task 7 Accuracy: 13.919999999999998
# Task 8 Accuracy: 14.729999999999999
# Task 9 Accuracy: 13.13
# Task 10 Accuracy: 9.02
# Task 11 Accuracy: 7.75
# Task 12 Accuracy: 13.61
# Task 13 Accuracy: 13.139999999999999
# Task 14 Accuracy: 10.6
# Task 15 Accuracy: 13.700000000000001
# Task 16 Accuracy: 13.79
# Task 17 Accuracy: 12.33
# Task 18 Accuracy: 14.38
# Task 19 Accuracy: 9.45
#
# [ 10-26 | 01:45 ] Task 1 | epoch 0: |██████████████████████████████████████████████████| loss: 0.17875175
# ******************************
# Evaluating Model
# ******************************
# ...

# %% [markdown]
# Table1 model GEM

# %%
# !python main.py --dataset seq-mnist --model gem --buffer_size 500 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='seq-mnist', experiment_id='cl', load_best_args=True, model='gem', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Task 0 Accuracy: 0.2364066193853428
# Task 1 Accuracy: 0.9794319294809012
# Task 2 Accuracy: 10.032017075773746
# Task 3 Accuracy: 24.87411883182276
# Task 4 Accuracy: 10.237014624306607
#
# [ 10-26 | 02:05 ] Task 1 | epoch 0: |██████████████████████████████████████████████████| loss: 0.00110956
# ******************************
# Evaluating Model
# ...

# %% [markdown]
# Table1 model iCaRL

# %%
# !python main.py --dataset seq-mnist --model icarl --buffer_size 200 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='seq-mnist', experiment_id='cl', load_best_args=True, model='icarl', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
#
# [ 10-26 | 02:07 ] Task 1 | epoch 0: |██████████████████████████████████████████████████| loss: 0.00029024
# ******************************
# Evaluating Model
# ******************************
# Task 0 Accuracy: 99.8581560283688
#
# Accuracy for 1 task(s): 	 [Class-IL]: 99.86 % 	 [Task-IL]: 99.91 %
#
# Task 1 Accuracy: 0.0
# ...

# %%
# !python main.py --dataset seq-mnist --model icarl --buffer_size 500 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='seq-mnist', experiment_id='cl', load_best_args=True, model='icarl', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
#
# [ 10-26 | 02:10 ] Task 1 | epoch 0: |██████████████████████████████████████████████████| loss: 0.00124216
# ******************************
# Evaluating Model
# ******************************
# Task 0 Accuracy: 99.52718676122932
#
# Accuracy for 1 task(s): 	 [Class-IL]: 99.53 % 	 [Task-IL]: 99.81 %
#
# Task 1 Accuracy: 6.8560235063663075
# ...

# %%
# !python main.py --dataset seq-mnist --model icarl --buffer_size 5120 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='seq-mnist', experiment_id='cl', load_best_args=True, model='icarl', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
#
# [ 10-26 | 02:11 ] Task 1 | epoch 0: |██████████████████████████████████████████████████| loss: 0.00016282
# ******************************
# Evaluating Model
# ******************************
# Task 0 Accuracy: 99.81087470449172
#
# Accuracy for 1 task(s): 	 [Class-IL]: 99.81 % 	 [Task-IL]: 99.91 %
#
# Task 1 Accuracy: 8.667972575905974
# ...

# %% [markdown]
# Table1 model DER++

# %%
# !python main.py --dataset seq-mnist --model derpp --buffer_size 500 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='seq-mnist', experiment_id='cl', load_best_args=True, model='derpp', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# ...
# 100% 9912422/9912422 [00:00<00:00, 122336195.14it/s]
# Extracting ./datasets/MNIST/MyMNIST/raw/train-images-idx3-ubyte.gz to ./datasets/MNIST/MyMNIST/raw
#
# ...
# 100% 28881/28881 [00:00<00:00, 125529216.40it/s]
# Extracting ./datasets/MNIST/MyMNIST/raw/train-labels-idx1-ubyte.gz to ./datasets/MNIST/MyMNIST/raw
#
# ...
# 100% 1648877/1648877 [00:00<00:00, 177089888.01it/s]
# Extracting ./datasets/MNIST/MyMNIST/raw/t10k-images-idx3-ubyte.gz to ./datasets/MNIST/MyMNIST/raw
#
# ...
# 100% 4542/4542 [00:00<00:00, 37208064.00it/s]
# Extracting ./datasets/MNIST/MyMNIST/raw/t10k-labels-idx1-ubyte.gz to ./datasets/MNIST/MyMNIST/raw
#
# ...
# 100% 9912422/9912422 [00:00<00:00, 344300903.03it/s]
# Extracting ./datasets/MNIST/MNIST/raw/train-images-idx3-ubyte.gz to ./datasets/MNIST/MNIST/raw
#
# ...

# %%
# !python main.py --dataset seq-mnist --model derpp --buffer_size 500 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='seq-mnist', experiment_id='cl', load_best_args=True, model='derpp', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# ...
# 100% 9912422/9912422 [00:00<00:00, 140318639.34it/s]
# Extracting ./datasets/MNIST/MyMNIST/raw/train-images-idx3-ubyte.gz to ./datasets/MNIST/MyMNIST/raw
#
# ...
# 100% 28881/28881 [00:00<00:00, 157934411.77it/s]
# Extracting ./datasets/MNIST/MyMNIST/raw/train-labels-idx1-ubyte.gz to ./datasets/MNIST/MyMNIST/raw
#
# ...
# 100% 1648877/1648877 [00:00<00:00, 172810879.48it/s]
# Extracting ./datasets/MNIST/MyMNIST/raw/t10k-images-idx3-ubyte.gz to ./datasets/MNIST/MyMNIST/raw
#
# ...
# 100% 4542/4542 [00:00<00:00, 22598492.01it/s]
# Extracting ./datasets/MNIST/MyMNIST/raw/t10k-labels-idx1-ubyte.gz to ./datasets/MNIST/MyMNIST/raw
#
# ...
# 100% 9912422/9912422 [00:00<00:00, 288858628.40it/s]
# Extracting ./datasets/MNIST/MNIST/raw/train-images-idx3-ubyte.gz to ./datasets/MNIST/MNIST/raw
#
# ...

# %%
# !python main.py --dataset seq-mnist --model derpp --buffer_size 500 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='seq-mnist', experiment_id='cl', load_best_args=True, model='derpp', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Task 0 Accuracy: 49.550827423167846
# Task 1 Accuracy: 0.0
# Task 2 Accuracy: 0.42689434364994666
# Task 3 Accuracy: 5.438066465256798
# Task 4 Accuracy: 13.716591023701463
#
# [ 10-28 | 21:19 ] Task 1 | epoch 0: |██████████████████████████████████████████████████| loss: 0.1062484
# ******************************
# Evaluating Model
# ...

# %%
# !python main.py --dataset seq-mnist --model derpp --buffer_size 200 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='seq-mnist', experiment_id='cl', load_best_args=True, model='derpp', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Task 0 Accuracy: 2.269503546099291
# Task 1 Accuracy: 0.0
# Task 2 Accuracy: 13.28708644610459
# Task 3 Accuracy: 6.495468277945619
# Task 4 Accuracy: 18.305597579425115
#
# [ 10-28 | 00:28 ] Task 1 | epoch 0: |██████████████████████████████████████████████████| loss: 0.03431272
# ******************************
# Evaluating Model
# ...

# %%
# !python main.py --dataset seq-mnist --model derpp --buffer_size 200 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='seq-mnist', experiment_id='cl', load_best_args=True, model='derpp', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Task 0 Accuracy: 15.69739952718676
# Task 1 Accuracy: 5.2399608227228205
# Task 2 Accuracy: 0.0
# Task 3 Accuracy: 30.664652567975832
# Task 4 Accuracy: 4.891578416540595
#
# [ 10-28 | 21:20 ] Task 1 | epoch 0: |██████████████████████████████████████████████████| loss: 0.03046981
# ******************************
# Evaluating Model
# ...

# %%
# !python main.py --dataset seq-mnist --model derpp --buffer_size 200 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='seq-mnist', experiment_id='cl', load_best_args=True, model='derpp', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Task 0 Accuracy: 40.99290780141844
# Task 1 Accuracy: 5.8765915768854065
# Task 2 Accuracy: 4.64247598719317
# Task 3 Accuracy: 3.3736153071500503
# Task 4 Accuracy: 0.05042864346949068
#
# [ 10-28 | 21:22 ] Task 1 | epoch 0: |██████████████████████████████████████████████████| loss: 0.02630975
# ******************************
# Evaluating Model
# ...

# %%
# !python main.py --dataset seq-mnist --model derpp --buffer_size 5120 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='seq-mnist', experiment_id='cl', load_best_args=True, model='derpp', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Task 0 Accuracy: 0.09456264775413711
# Task 1 Accuracy: 2.0078354554358473
# Task 2 Accuracy: 2.934898612593383
# Task 3 Accuracy: 0.10070493454179255
# Task 4 Accuracy: 41.90620272314675
#
# [ 10-28 | 00:30 ] Task 1 | epoch 0: |██████████████████████████████████████████████████| loss: 0.02208632
# ******************************
# ...

# %%
# !python main.py --dataset seq-mnist --model derpp --buffer_size 5120 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='seq-mnist', experiment_id='cl', load_best_args=True, model='derpp', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Task 0 Accuracy: 2.127659574468085
# Task 1 Accuracy: 1.1753183153770812
# Task 2 Accuracy: 0.3735325506937033
# Task 3 Accuracy: 0.4028197381671702
# Task 4 Accuracy: 40.292486132123045
#
# [ 10-28 | 00:42 ] Task 1 | epoch 0: |██████████████████████████████████████████████████| loss: 0.02924113
# ******************************
# ...

# %%
# !python main.py --dataset rot-mnist --model derpp --buffer_size 5120 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='rot-mnist', experiment_id='cl', load_best_args=True, model='derpp', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# Task 0 Accuracy: 6.21
# Task 1 Accuracy: 11.85
# Task 2 Accuracy: 10.63
# Task 3 Accuracy: 15.659999999999998
# Task 4 Accuracy: 10.31
# Task 5 Accuracy: 7.46
# Task 6 Accuracy: 6.97
# Task 7 Accuracy: 8.48
# Task 8 Accuracy: 13.41
# Task 9 Accuracy: 7.7700000000000005
# Task 10 Accuracy: 6.5
# Task 11 Accuracy: 6.67
# Task 12 Accuracy: 11.67
# Task 13 Accuracy: 8.72
# Task 14 Accuracy: 6.7
# Task 15 Accuracy: 8.649999999999999
# Task 16 Accuracy: 6.7299999999999995
# Task 17 Accuracy: 15.85
# Task 18 Accuracy: 8.27
# Task 19 Accuracy: 6.819999999999999
#
# [ 10-28 | 00:47 ] Task 1 | epoch 0: |██████████████████████████████████████████████████| loss: 0.43459308
# ******************************
# Evaluating Model
# ******************************
# Task 0 Accuracy: 95.05
#
# ...

# %%
# !python main.py --dataset rot-mnist --model derpp --buffer_size 500 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='rot-mnist', experiment_id='cl', load_best_args=True, model='derpp', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# Task 0 Accuracy: 5.07
# Task 1 Accuracy: 8.799999999999999
# Task 2 Accuracy: 9.67
# Task 3 Accuracy: 7.91
# Task 4 Accuracy: 8.55
# Task 5 Accuracy: 9.31
# Task 6 Accuracy: 5.7
# Task 7 Accuracy: 7.449999999999999
# Task 8 Accuracy: 8.17
# Task 9 Accuracy: 10.45
# Task 10 Accuracy: 6.140000000000001
# Task 11 Accuracy: 5.27
# Task 12 Accuracy: 10.51
# Task 13 Accuracy: 10.09
# Task 14 Accuracy: 5.42
# Task 15 Accuracy: 8.7
# Task 16 Accuracy: 7.07
# Task 17 Accuracy: 9.520000000000001
# Task 18 Accuracy: 10.33
# Task 19 Accuracy: 5.19
#
# [ 10-28 | 00:55 ] Task 1 | epoch 0: |██████████████████████████████████████████████████| loss: 0.45608944
# ******************************
# Evaluating Model
# ******************************
# Task 0 Accuracy: 94.46
#
# Accuracy for 1 task(s): 94.46 %
# ...

# %%
# !python main.py --dataset rot-mnist --model derpp --buffer_size 200 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='rot-mnist', experiment_id='cl', load_best_args=True, model='derpp', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# Task 0 Accuracy: 6.67
# Task 1 Accuracy: 7.1499999999999995
# Task 2 Accuracy: 6.78
# Task 3 Accuracy: 15.98
# Task 4 Accuracy: 13.22
# Task 5 Accuracy: 5.74
# Task 6 Accuracy: 12.06
# Task 7 Accuracy: 7.01
# Task 8 Accuracy: 16.76
# Task 9 Accuracy: 5.7299999999999995
# Task 10 Accuracy: 15.58
# Task 11 Accuracy: 13.320000000000002
# Task 12 Accuracy: 15.290000000000001
# Task 13 Accuracy: 7.359999999999999
# Task 14 Accuracy: 16.16
# Task 15 Accuracy: 16.3
# Task 16 Accuracy: 15.959999999999999
# Task 17 Accuracy: 15.55
# Task 18 Accuracy: 12.389999999999999
# Task 19 Accuracy: 15.17
#
# [ 10-28 | 01:04 ] Task 1 | epoch 0: |██████████████████████████████████████████████████| loss: 0.60939634
# ******************************
# Evaluating Model
# ******************************
# ...

# %%
# !python main.py --dataset rot-mnist --model derpp --buffer_size 500 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='rot-mnist', experiment_id='cl', load_best_args=True, model='derpp', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# Task 0 Accuracy: 9.120000000000001
# Task 1 Accuracy: 5.54
# Task 2 Accuracy: 8.12
# Task 3 Accuracy: 4.83
# Task 4 Accuracy: 11.03
# Task 5 Accuracy: 6.069999999999999
# Task 6 Accuracy: 9.4
# Task 7 Accuracy: 5.6899999999999995
# Task 8 Accuracy: 10.08
# Task 9 Accuracy: 7.6499999999999995
# Task 10 Accuracy: 4.9399999999999995
# Task 11 Accuracy: 8.290000000000001
# Task 12 Accuracy: 10.34
# Task 13 Accuracy: 4.859999999999999
# Task 14 Accuracy: 7.5
# Task 15 Accuracy: 5.96
# Task 16 Accuracy: 4.88
# Task 17 Accuracy: 9.89
# Task 18 Accuracy: 9.15
# Task 19 Accuracy: 9.32
#
# [ 10-28 | 01:46 ] Task 1 | epoch 0: |██████████████████████████████████████████████████| loss: 0.36362088
# ******************************
# Evaluating Model
# ******************************
# Task 0 Accuracy: 95.03
#
# ...

# %%
# !python main.py --dataset rot-mnist --model derpp --buffer_size 500 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='rot-mnist', experiment_id='cl', load_best_args=True, model='derpp', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# Task 0 Accuracy: 9.29
# Task 1 Accuracy: 10.11
# Task 2 Accuracy: 10.0
# Task 3 Accuracy: 9.42
# Task 4 Accuracy: 9.1
# Task 5 Accuracy: 10.11
# Task 6 Accuracy: 9.59
# Task 7 Accuracy: 11.04
# Task 8 Accuracy: 11.020000000000001
# Task 9 Accuracy: 10.209999999999999
# Task 10 Accuracy: 10.12
# Task 11 Accuracy: 9.700000000000001
# Task 12 Accuracy: 9.51
# Task 13 Accuracy: 10.17
# Task 14 Accuracy: 9.48
# Task 15 Accuracy: 9.950000000000001
# Task 16 Accuracy: 9.46
# Task 17 Accuracy: 9.69
# Task 18 Accuracy: 11.62
# Task 19 Accuracy: 8.3
#
# [ 10-28 | 01:55 ] Task 1 | epoch 0: |██████████████████████████████████████████████████| loss: 0.42736533
# ******************************
# Evaluating Model
# ******************************
# Task 0 Accuracy: 94.39999999999999
#
# ...

# %%
# !python main.py --dataset rot-mnist --model derpp --buffer_size 200 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='rot-mnist', experiment_id='cl', load_best_args=True, model='derpp', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# Task 0 Accuracy: 9.8
# Task 1 Accuracy: 8.27
# Task 2 Accuracy: 8.98
# Task 3 Accuracy: 11.63
# Task 4 Accuracy: 9.76
# Task 5 Accuracy: 8.48
# Task 6 Accuracy: 10.07
# Task 7 Accuracy: 10.35
# Task 8 Accuracy: 8.4
# Task 9 Accuracy: 9.8
# Task 10 Accuracy: 12.049999999999999
# Task 11 Accuracy: 9.959999999999999
# Task 12 Accuracy: 11.26
# Task 13 Accuracy: 10.12
# Task 14 Accuracy: 8.99
# Task 15 Accuracy: 10.299999999999999
# Task 16 Accuracy: 9.2
# Task 17 Accuracy: 7.95
# Task 18 Accuracy: 8.959999999999999
# Task 19 Accuracy: 6.78
#
# [ 10-28 | 02:03 ] Task 1 | epoch 0: |██████████████████████████████████████████████████| loss: 0.70934987
# ******************************
# Evaluating Model
# ******************************
# Task 0 Accuracy: 92.15
#
# Accuracy for 1 task(s): 92.15 %
# ...

# %%
# !python main.py --dataset rot-mnist --model derpp --buffer_size 200 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='rot-mnist', experiment_id='cl', load_best_args=True, model='derpp', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# Task 0 Accuracy: 8.06
# Task 1 Accuracy: 14.399999999999999
# Task 2 Accuracy: 8.43
# Task 3 Accuracy: 17.03
# Task 4 Accuracy: 7.32
# Task 5 Accuracy: 16.72
# Task 6 Accuracy: 5.7700000000000005
# Task 7 Accuracy: 7.969999999999999
# Task 8 Accuracy: 14.729999999999999
# Task 9 Accuracy: 12.78
# Task 10 Accuracy: 8.37
# Task 11 Accuracy: 6.3100000000000005
# Task 12 Accuracy: 8.559999999999999
# Task 13 Accuracy: 8.91
# Task 14 Accuracy: 8.83
# Task 15 Accuracy: 8.16
# Task 16 Accuracy: 7.79
# Task 17 Accuracy: 14.64
# Task 18 Accuracy: 7.9799999999999995
# Task 19 Accuracy: 7.07
#
# [ 10-28 | 02:12 ] Task 1 | epoch 0: |██████████████████████████████████████████████████| loss: 0.63247979
# ******************************
# Evaluating Model
# ******************************
# Task 0 Accuracy: 93.11
# ...

# %%
# !python main.py --dataset rot-mnist --model derpp --buffer_size 5120 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='rot-mnist', experiment_id='cl', load_best_args=True, model='derpp', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# Task 0 Accuracy: 12.17
# Task 1 Accuracy: 12.33
# Task 2 Accuracy: 9.36
# Task 3 Accuracy: 10.94
# Task 4 Accuracy: 12.030000000000001
# Task 5 Accuracy: 7.53
# Task 6 Accuracy: 8.61
# Task 7 Accuracy: 11.360000000000001
# Task 8 Accuracy: 7.42
# Task 9 Accuracy: 11.459999999999999
# Task 10 Accuracy: 8.88
# Task 11 Accuracy: 11.92
# Task 12 Accuracy: 9.36
# Task 13 Accuracy: 12.53
# Task 14 Accuracy: 7.28
# Task 15 Accuracy: 10.38
# Task 16 Accuracy: 7.75
# Task 17 Accuracy: 9.73
# Task 18 Accuracy: 7.2700000000000005
# Task 19 Accuracy: 7.6899999999999995
#
# [ 10-28 | 02:21 ] Task 1 | epoch 0: |██████████████████████████████████████████████████| loss: 0.544761
# ******************************
# Evaluating Model
# ******************************
# Task 0 Accuracy: 94.78
#
# ...

# %%
# !python main.py --dataset rot-mnist --model derpp --buffer_size 5120 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='rot-mnist', experiment_id='cl', load_best_args=True, model='derpp', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# Task 0 Accuracy: 8.870000000000001
# Task 1 Accuracy: 9.790000000000001
# Task 2 Accuracy: 6.279999999999999
# Task 3 Accuracy: 5.57
# Task 4 Accuracy: 9.569999999999999
# Task 5 Accuracy: 8.14
# Task 6 Accuracy: 9.16
# Task 7 Accuracy: 7.71
# Task 8 Accuracy: 8.08
# Task 9 Accuracy: 7.42
# Task 10 Accuracy: 5.970000000000001
# Task 11 Accuracy: 7.68
# Task 12 Accuracy: 7.3
# Task 13 Accuracy: 8.05
# Task 14 Accuracy: 6.74
# Task 15 Accuracy: 8.98
# Task 16 Accuracy: 5.99
# Task 17 Accuracy: 7.779999999999999
# Task 18 Accuracy: 7.539999999999999
# Task 19 Accuracy: 6.87
#
# [ 10-28 | 02:30 ] Task 1 | epoch 0: |██████████████████████████████████████████████████| loss: 0.45586634
# ******************************
# Evaluating Model
# ******************************
# ...

# %% [markdown]
# Buffer Size 1

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
 
X_labels = ['Task 1', 'Task 2', 'Task 3', 'Task 4', 'Task 5']

Y_labels = ['After Task 1', 'After Task 2', 'After Task 3', 'After Task 4', 'After Task 5']
plt.rcParams["figure.autolayout"] = True

A = [
	[99.90543735, 0, 0, 0, 0], 
	[4.255319149, 98.13907933, 0, 0, 0], 
	[0.2364066194, 0, 99.46638207, 0, 0], 
	[1.276595745, 0, 0, 99.54682779, 0], 
	[2.553191489, 0, 0, 0.2014098691, 98.23499748]
]
B = [
	[99.90543735, 0, 0, 0, 0], 
	[3.924349882, 98.09010774, 0, 0, 0], 
	[0.1891252955, 0, 99.41302028, 0, 0], 
	[1.513002364, 0, 0, 99.64753273, 0], 
	[2.742316785, 0, 0, 0.3021148036, 98.23499748]
]
C =  [
	[99.90543735, 0, 0, 0, 0], 
	[4.208037825, 98.13907933, 0, 0, 0], 
	[0.2364066194, 0, 99.51974386, 0, 0], 
	[1.323877069, 0, 0, 99.54682779, 0], 
	[2.647754137, 0, 0, 0.2014098691, 98.23499748]
]
fig, (ax1,ax2,ax3) = plt.subplots(ncols=3, figsize=(15, 5), sharex =True)
df = pd.DataFrame(A)
df2 = pd.DataFrame(B)
df3 = pd.DataFrame(C)
ax1.set_title ('Stable Model')
ax2.set_title ('Working Model')
ax3.set_title ('Plastic Model')

sns.heatmap(df, cmap='viridis',annot=True, fmt=".2f"  , ax=ax1, xticklabels=X_labels, yticklabels=Y_labels,cbar=False)
sns.heatmap(df2, cmap='viridis',annot=True, fmt=".2f" , ax=ax2,xticklabels=X_labels, yticklabels=Y_labels,cbar=False) 
sns.heatmap(df3, cmap='viridis',annot=True, fmt=".2f" , ax=ax3,xticklabels=X_labels, yticklabels=Y_labels,cbar=False)
#plt.yticks(rotation=0) 
for ax in (ax1,ax2,ax3): 
    #ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
    ax.set_yticklabels(ax.get_yticklabels(), rotation=0)
plt.show()

# %% [markdown]
# Buffer Size = 1000

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
 
X_labels = ['Task 1', 'Task 2', 'Task 3', 'Task 4', 'Task 5']

Y_labels = ['After Task 1', 'After Task 2', 'After Task 3', 'After Task 4', 'After Task 5']
plt.rcParams["figure.autolayout"] = True

A = [
	[99.95271868, 0, 0, 0, 0], 
	[99.38534279, 95.49461312, 0, 0, 0], 
	[99.05437352, 94.417238, 92.63607257, 0, 0], 
	[98.62884161, 93.29089128, 93.86339381, 93.75629406, 0], 
	[98.15602837, 92.31145935, 90.28815368, 93.45417925, 88.55269793]
]
B = [
	[99.95271868, 0, 0, 0, 0], 
	[99.29078014, 95.7884427, 0, 0, 0], 
	[98.95981087, 94.07443683, 93.75667022, 0, 0], 
	[98.58156028, 92.80117532, 93.81003202, 94.10876133, 0], 
	[97.96690307, 92.21351616, 89.54108858, 93.05135952, 90.21684317]
]
C =  [
	[99.95271868, 0, 0, 0, 0], 
	[99.33806147, 95.49461312, 0, 0, 0], 
	[99.05437352, 94.417238, 92.90288154, 0, 0], 
	[98.62884161, 93.24191969, 93.86339381, 93.75629406, 0], 
	[98.10874704, 92.31145935, 90.23479189, 93.40382679, 88.65355522]
]
fig, (ax1,ax2,ax3) = plt.subplots(ncols=3, figsize=(15, 5), sharex =True)
df = pd.DataFrame(A)
df2 = pd.DataFrame(B)
df3 = pd.DataFrame(C)
ax1.set_title ('Stable Model')
ax2.set_title ('Working Model')
ax3.set_title ('Plastic Model')

sns.heatmap(df, cmap='viridis',annot=True, fmt=".2f"  , ax=ax1, xticklabels=X_labels, yticklabels=Y_labels,cbar=False)
sns.heatmap(df2, cmap='viridis',annot=True, fmt=".2f" , ax=ax2,xticklabels=X_labels, yticklabels=Y_labels,cbar=False) 
sns.heatmap(df3, cmap='viridis',annot=True, fmt=".2f" , ax=ax3,xticklabels=X_labels, yticklabels=Y_labels,cbar=False)
#plt.yticks(rotation=0) 
for ax in (ax1,ax2,ax3): 
    #ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
    ax.set_yticklabels(ax.get_yticklabels(), rotation=0)
plt.show()

# %% [markdown]
# Buffer Size = 1e6

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
 
X_labels = ['Task 1', 'Task 2', 'Task 3', 'Task 4', 'Task 5']

Y_labels = ['After Task 1', 'After Task 2', 'After Task 3', 'After Task 4', 'After Task 5']
plt.rcParams["figure.autolayout"] = True

A = [
	[99.95271868, 0, 0, 0, 0], 
	[99.43262411, 96.32713026, 0, 0, 0], 
	[99.24349882, 96.08227228, 94.07684098, 0, 0], 
	[99.05437352, 95.44564153, 95.78441836, 93.25276939, 0], 
	[98.58156028, 94.80901077, 94.45037353, 94.7633434, 87.79626828]
]
B = [
	[99.95271868, 0, 0, 0, 0], 
	[99.43262411, 96.03330069, 0, 0, 0], 
	[99.24349882, 95.34769833, 96.05122732, 0, 0], 
	[99.05437352, 95.34769833, 95.4642476, 94.4612286, 0], 
	[98.58156028, 94.56415279, 93.75667022, 94.81369587, 89.15784165]
]
C =  [
	[99.95271868, 0, 0, 0, 0], 
	[99.43262411, 96.32713026, 0, 0, 0], 
	[99.24349882, 96.08227228, 94.18356457, 0, 0], 
	[99.05437352, 95.49461312, 95.73105656, 93.40382679, 0], 
	[98.58156028, 94.80901077, 94.23692636, 94.7633434, 87.99798285]
]
fig, (ax1,ax2,ax3) = plt.subplots(ncols=3, figsize=(15, 5), sharex =True)
df = pd.DataFrame(A)
df2 = pd.DataFrame(B)
df3 = pd.DataFrame(C)
ax1.set_title ('Stable Model')
ax2.set_title ('Working Model')
ax3.set_title ('Plastic Model')

sns.heatmap(df, cmap='viridis',annot=True, fmt=".2f"  , ax=ax1, xticklabels=X_labels, yticklabels=Y_labels,cbar=False)
sns.heatmap(df2, cmap='viridis',annot=True, fmt=".2f" , ax=ax2,xticklabels=X_labels, yticklabels=Y_labels,cbar=False) 
sns.heatmap(df3, cmap='viridis',annot=True, fmt=".2f" , ax=ax3,xticklabels=X_labels, yticklabels=Y_labels,cbar=False)
#plt.yticks(rotation=0) 
for ax in (ax1,ax2,ax3): 
    #ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
    ax.set_yticklabels(ax.get_yticklabels(), rotation=0)
plt.show()

# %% [markdown]
# S-CIFAR-100,
# CLS-ER with 50 epochs,
# Buffer Size 500

# %%
# !python main.py --dataset seq-cifar100 --model clser --buffer_size 500 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='seq-cifar100', experiment_id='cl', load_best_args=True, model='clser', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# Task 0 Accuracy: 0.0
# Task 1 Accuracy: 0.8
# Task 2 Accuracy: 0.0
# Task 3 Accuracy: 0.0
# Task 4 Accuracy: 0.0
# Task 5 Accuracy: 0.0
# Task 6 Accuracy: 0.0
# Task 7 Accuracy: 0.0
# Task 8 Accuracy: 8.9
# Task 9 Accuracy: 0.0
#
# /content/CLS-ER/models/clser.py:129: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:1420.)
#   ema_param.data.mul_(alpha).add_(1 - alpha, param.data)
# [ 12-11 | 19:10 ] Task 1 | epoch 49: |██████████████████████████████████████████████████| loss: 0.00502697
# ******************************
# Evaluating Model
# ******************************
# Task 0 Accuracy: 87.3
#
# ...

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
 
X_labels = ['Task 1', 'Task 2', 'Task 3', 'Task 4', 'Task 5','Task 6', 'Task 7', 'Task 8', 'Task 9', 'Task 10']

Y_labels = ['After Task 1', 'After Task 2', 'After Task 3', 'After Task 4', 'After Task 5','After Task 6', 'After Task 7', 'After Task 8', 'After Task 9', 'After Task 10']
plt.rcParams["figure.autolayout"] = True

A = [
	[87.3, 0, 0, 0, 0, 0, 0, 0, 0, 0], 
	[51.2, 85.4, 0, 0, 0, 0, 0, 0, 0, 0], 
	[43.9, 45.8, 88, 0, 0, 0, 0, 0, 0, 0], 
	[38.2, 30.6, 47.3, 89.5, 0, 0, 0, 0, 0, 0], 
	[30.6, 30, 30.8, 41, 89.4, 0, 0, 0, 0, 0], 
	[25.9, 32, 37.7, 32.4, 43.8, 89.2, 0, 0, 0, 0], 
	[22.5, 27.8, 28.8, 24.5, 32.1, 46.1, 87.9, 0, 0, 0], 
	[22, 26.8, 23.4, 22.3, 24.5, 36.2, 25.5, 89.1, 0, 0], 
	[16.6, 18.8, 21.4, 21.4, 21.1, 29.7, 24.8, 35.2, 90.1, 0], 
	[17.2, 15.6, 21.7, 14.8, 19.8, 21.1, 19.2, 20.1, 23.2, 93.7]
]
B = [
	[88.5, 0, 0, 0, 0, 0, 0, 0, 0, 0], 
	[49.3, 86, 0, 0, 0, 0, 0, 0, 0, 0], 
	[42.9, 45.4, 87.6, 0, 0, 0, 0, 0, 0, 0], 
	[36.8, 29.2, 46.2, 89.5, 0, 0, 0, 0, 0, 0], 
	[29.6, 29.7, 29.8, 41.1, 89.4, 0, 0, 0, 0, 0], 
	[25.8, 31.2, 36, 32.1, 45.1, 89.2, 0, 0, 0, 0], 
	[21.2, 27.6, 28.5, 24.5, 31.5, 45.4, 88.8, 0, 0, 0], 
	[21.5, 25.5, 22.2, 21.4, 24, 35.2, 24.4, 89.4, 0, 0], 
	[16, 18, 20.4, 20.6, 21.2, 29.9, 25.2, 36.3, 89.8, 0], 
	[16.6, 15.8, 20.7, 14.7, 19.8, 19.9, 18.4, 19.8, 22.7, 94.2]
]
C =  [
	[81.4, 0, 0, 0, 0, 0, 0, 0, 0, 0], 
	[85.9, 27.7, 0, 0, 0, 0, 0, 0, 0, 0], 
	[74.5, 70.4, 42.1, 0, 0, 0, 0, 0, 0, 0], 
	[64.6, 66.9, 74.9, 23.4, 0, 0, 0, 0, 0, 0], 
	[52.8, 57.4, 70.6, 72.9, 39, 0, 0, 0, 0, 0], 
	[43.2, 51.1, 58.8, 64.9, 72.1, 32.9, 0, 0, 0, 0], 
	[37.9, 45.8, 52.7, 57.1, 64.5, 70.8, 27.3, 0, 0, 0], 
	[36, 42, 42, 46.3, 56.3, 64.7, 66.6, 40.2, 0, 0], 
	[31.1, 36.5, 38.7, 44.5, 49.7, 55.6, 53.2, 69.1, 27.6, 0], 
	[27.2, 29.6, 35.4, 37.2, 43.7, 50.1, 46.9, 65.2, 66.7, 36.8]
]
fig, (ax1,ax2,ax3) = plt.subplots(ncols=3, figsize=(15, 5), sharex =True)
df = pd.DataFrame(A)
df2 = pd.DataFrame(B)
df3 = pd.DataFrame(C)
ax1.set_title ('Stable Model',fontdict={'fontsize': 20})
ax2.set_title ('Working Model',fontdict={'fontsize': 20})
ax3.set_title ('Plastic Model',fontdict={'fontsize': 20})

sns.heatmap(df, cmap='viridis',annot=True, fmt=".1f"  , ax=ax1, xticklabels=X_labels, yticklabels=Y_labels,cbar=False)
sns.heatmap(df2, cmap='viridis',annot=True, fmt=".1f" , ax=ax2,xticklabels=X_labels, yticklabels=Y_labels,cbar=False) 
sns.heatmap(df3, cmap='viridis',annot=True, fmt=".1f" , ax=ax3,xticklabels=X_labels, yticklabels=Y_labels,cbar=False)
#plt.yticks(rotation=0) 
for ax in (ax1,ax2,ax3): 
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
    ax.set_yticklabels(ax.get_yticklabels(), rotation=0)
plt.show()

# %% [markdown]
# S-CIFAR-100, CLS-ER and DER++ with 5 epochs, Buffer Size 200 500 5120

# %%
# !python main.py --dataset seq-cifar100 --model clser --buffer_size 200 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='seq-cifar100', experiment_id='cl', load_best_args=True, model='clser', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Task 0 Accuracy: 9.1
# Task 1 Accuracy: 0.0
# Task 2 Accuracy: 0.0
# Task 3 Accuracy: 0.0
# Task 4 Accuracy: 0.7000000000000001
# Task 5 Accuracy: 0.0
# Task 6 Accuracy: 0.2
# Task 7 Accuracy: 0.0
# Task 8 Accuracy: 0.0
# Task 9 Accuracy: 0.0
#
# ...

# %%
# !python main.py --dataset seq-cifar100 --model derpp --buffer_size 200 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='seq-cifar100', experiment_id='cl', load_best_args=True, model='derpp', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# ...
# 100% 169001437/169001437 [00:01<00:00, 104189597.47it/s]
# Extracting ./datasets/CIFAR100/cifar-100-python.tar.gz to ./datasets/CIFAR100
# Task 0 Accuracy: 9.0
# Task 1 Accuracy: 0.0
# Task 2 Accuracy: 0.0
# Task 3 Accuracy: 0.7000000000000001
# Task 4 Accuracy: 0.2
# Task 5 Accuracy: 0.0
# Task 6 Accuracy: 0.0
# Task 7 Accuracy: 0.0
# Task 8 Accuracy: 0.0
# Task 9 Accuracy: 0.0
#
# [ 12-11 | 18:54 ] Task 1 | epoch 4: |██████████████████████████████████████████████████| loss: 0.97245359
# ******************************
# Evaluating Model
# ******************************
# Task 0 Accuracy: 71.6
#
# Accuracy for 1 task(s): 	 [Class-IL]: 71.6 % 	 [Task-IL]: 71.6 %
#
# Task 1 Accuracy: 0.0
# [ 12-11 | 18:55 ] Task 2 | epoch 4: |██████████████████████████████████████████████████| loss: 1.11937892
# ...

# %%
# !python main.py --dataset seq-cifar100 --model derpp --buffer_size 500 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='seq-cifar100', experiment_id='cl', load_best_args=True, model='derpp', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# Task 0 Accuracy: 0.0
# Task 1 Accuracy: 0.0
# Task 2 Accuracy: 4.5
# Task 3 Accuracy: 0.0
# Task 4 Accuracy: 0.4
# Task 5 Accuracy: 0.0
# Task 6 Accuracy: 1.3
# Task 7 Accuracy: 0.0
# Task 8 Accuracy: 0.0
# Task 9 Accuracy: 0.3
#
# [ 12-11 | 20:26 ] Task 1 | epoch 4: |██████████████████████████████████████████████████| loss: 0.89105582
# ******************************
# Evaluating Model
# ******************************
# Task 0 Accuracy: 71.8
#
# Accuracy for 1 task(s): 	 [Class-IL]: 71.8 % 	 [Task-IL]: 71.8 %
#
# Task 1 Accuracy: 0.0
# [ 12-11 | 20:27 ] Task 2 | epoch 4: |██████████████████████████████████████████████████| loss: 1.08397937
# ******************************
# Evaluating Model
# ******************************
# Task 0 Accuracy: 40.300000000000004
# ...

# %%
# !python main.py --dataset seq-cifar100 --model clser --buffer_size 500 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='seq-cifar100', experiment_id='cl', load_best_args=True, model='clser', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# Task 0 Accuracy: 0.0
# Task 1 Accuracy: 0.0
# Task 2 Accuracy: 0.0
# Task 3 Accuracy: 0.0
# Task 4 Accuracy: 0.0
# Task 5 Accuracy: 0.0
# Task 6 Accuracy: 0.0
# Task 7 Accuracy: 9.8
# Task 8 Accuracy: 0.0
# Task 9 Accuracy: 0.0
#
# /content/CLS-ER/models/clser.py:129: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:1420.)
#   ema_param.data.mul_(alpha).add_(1 - alpha, param.data)
# [ 12-11 | 20:36 ] Task 1 | epoch 4: |██████████████████████████████████████████████████| loss: 0.54869348
# ******************************
# Evaluating Model
# ******************************
# Task 0 Accuracy: 65.7
#
# ...

# %%
# !python main.py --dataset seq-cifar100 --model clser --buffer_size 5120 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='seq-cifar100', experiment_id='cl', load_best_args=True, model='clser', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# Task 0 Accuracy: 0.0
# Task 1 Accuracy: 0.0
# Task 2 Accuracy: 4.7
# Task 3 Accuracy: 0.0
# Task 4 Accuracy: 0.0
# Task 5 Accuracy: 0.0
# Task 6 Accuracy: 4.1000000000000005
# Task 7 Accuracy: 0.0
# Task 8 Accuracy: 0.0
# Task 9 Accuracy: 0.0
#
# /content/CLS-ER/models/clser.py:129: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:1420.)
#   ema_param.data.mul_(alpha).add_(1 - alpha, param.data)
# [ 12-11 | 20:46 ] Task 1 | epoch 4: |██████████████████████████████████████████████████| loss: 0.87057757
# ******************************
# Evaluating Model
# ******************************
# ...

# %%
# !python main.py --dataset seq-cifar100 --model derpp --buffer_size 5120 --load_best_args
# Out:
# Namespace(csv_log=False, dataset='seq-cifar100', experiment_id='cl', load_best_args=True, model='derpp', notes=None, output_dir='experiments', seed=None, tensorboard=False, validation=False)
# Task 0 Accuracy: 0.0
# Task 1 Accuracy: 0.0
# Task 2 Accuracy: 9.9
# Task 3 Accuracy: 0.0
# Task 4 Accuracy: 0.0
# Task 5 Accuracy: 0.0
# Task 6 Accuracy: 0.0
# Task 7 Accuracy: 0.0
# Task 8 Accuracy: 0.0
# Task 9 Accuracy: 0.0
#
# [ 12-11 | 20:56 ] Task 1 | epoch 4: |██████████████████████████████████████████████████| loss: 1.26677632
# ******************************
# Evaluating Model
# ******************************
# Task 0 Accuracy: 69.39999999999999
#
# Accuracy for 1 task(s): 	 [Class-IL]: 69.4 % 	 [Task-IL]: 69.4 %
#
# Task 1 Accuracy: 0.0
# [ 12-11 | 20:57 ] Task 2 | epoch 4: |██████████████████████████████████████████████████| loss: 2.0042367
# ******************************
# Evaluating Model
# ******************************
# Task 0 Accuracy: 55.7
# Task 1 Accuracy: 67.9
#
# ...
